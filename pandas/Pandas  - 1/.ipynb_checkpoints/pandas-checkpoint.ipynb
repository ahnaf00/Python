# %%
import pandas as pd

df = pd.read_csv("student_data.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("student_data.csv")
#       4 print(df)
#
# AttributeError: module 'pandas' has no attribute 'read_csv'
